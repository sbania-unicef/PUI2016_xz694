# %%
from __future__ import print_function
__author__ = "Federica B. Bianco, CUSP NYU 2016"

# %% [markdown]
# # Create a <i>reproducible research</i> chunk of code
#
# That means we want the reader to be able to reproduce every step of the work we do.
#
# If our work includes the use of stochastic processes and random variables that gets tricky: how do we assure the random draw gives the same number to the user that it gave to me? That is not random!
#
# That becomes possible because computers are unable to poduce truly random numbers. When we ask a computer to generate a random number, it will in fact generate a "pseudo random" number. The number will be randon in the sanse that it will be some number between, for example, 0 and 1 if we ask for a **uniform random distribution** or a number near 0 if we aks for a **Gaussian distribution with mean 0**. <i> But the sequence of pseudo-random numbers that a compujter generates will depend on its **seed**: if you know the seed you know all the numbers that are "randomely" drawn</i>.
#
# You can read more about pseudorandom number generation in this wikipedia article https://en.wikipedia.org/wiki/Pseudorandom_number_generator
#
# Fill in the empty cells below with code, as directed.

# %%
import os
import sys

# you can use the numpy library for random number generation: 
# http://docs.scipy.org/doc/numpy/reference/routines.random.html

import numpy as np

# %% [markdown]
# ## THIS IS THE MOST IMPORTANT PIECE OF THIS CODE!
# ### give numpy as seed for this code to be reproducible
# (no points if this is wrong)
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html

# %%
# code here...
np.random.seed(21)

# %% [markdown]
# ### 1. Generate random distributions. use the function
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html
# ### to generate 100 2-dimensional random datapoints in a gaussian distribution
#
# call the array ReprRand

# %%
# code here...
ReprRand = np.random.randn(2,100)

# %% [markdown]
# #### if you did this correctly the shape of ReprRand will be (2, 100)

# %%
# run this cell
ReprRand.shape
# Out:
# (2, 100)

# %% [markdown]
# ## 2. use the same function to generate 50 more random 2x100 numpy arrays and store them in ReprRandAll, all with different mean.
#
# np.random.randn creates a distribution with mean 0 and standard deviation 1 by default.
#
# To obtain a gaussian distribution with a mean different than 1 using np.random.randn you must add your new mean (it is explained in the dunction documentation for which I already gave you the link)
#
# If you want to change the standard deviation (sigma) as well you multiply the distribution by the new sigma.
#
# You can do it in a for loop. The first line of code I included generates an array of zeros that you can fill in with your new numbers.

# %%
ReprRandAll = np.zeros((50, 2, 100))

for i in range(50):
    #code here...
    ReprRandAll[i] = np.random.randn(2, 100) + i

# %%
# run this cell
ReprRandAll.shape
# Out:
# (50, 2, 100)

# %% [markdown]
# ## 3. now plot them:
#
# you can use the matplotlib library, and the function scatter(), but that would plot everything in the same color unless you ask it not to. For convenience, let's use the function plot() which by default plots lines, and tell it to plot points (in addition plot is actually more efficient, so if you have a large dataset you may want to consider using plot with points for it anyways)
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# http://matplotlib.org/users/pyplot_tutorial.html

# %%
import pylab as pl
# %pylab inline
# the last line of code makes the plot show up within the notebook. 
# Always include it so that your homework notebooks are rendered and we can see
# what you wanted your results to be. 

# code here
for i in range(50):
    pl.figure()
    pl.plot(ReprRandAll[i], 'o') #results do not seem to show the right points...Way of indexing....?
    pl.title('Figure %d: Random Datapoints in Gaussian Distribution (Mean = %d)' %(i+1,i), fontsize = 16)
    pl.xlabel('X Values - Random', fontsize = 14)
    pl.ylabel('Y Values - Random', fontsize = 14)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Always add a caption to each of your homework figures.
# And remember to give your labels some names!
# This is a general rule. Without the caption or axis labels this portion of the HW will not get points. Make sure the font in the labels is large enough to be readable.
#
# ## Figure 1:
#
# Random Datapoints in Gaussian Distribution (Mean = 0)

# %% [markdown]
# ## Challenge
#
# It is easier to give the same mean and standard deviation to each dimension. Can you give two different values for the mean along the x- and the mean along the y- axis for each of the 50 distributions if you have not done so? If you are an experienced coder, can you do it in a single line?

# %%
# code here...

# %%
# plot here...

# %%
ReprRandAll[1]
# Out:
# array([[ 2.80103416,  0.9640005 ,  2.9847578 ,  2.42273929, -0.80004978,
#          0.93859187,  1.54961701,  0.80046826,  2.09921662,  1.40995917,
#          1.58022931,  0.82378695, -0.71223964,  1.39886456, -0.02755275,
#          1.84268068,  1.26014926,  3.90322608,  1.40780481, -0.75477581,
#          3.28630069,  1.55037493,  2.22199945,  2.46033294,  0.12604004,
#          0.04880558,  1.85644923, -0.01237018, -0.77729301,  0.35760889,
#          0.82598178,  1.67723074,  0.55040995,  0.33050737,  1.42860053,
#          1.1439113 ,  1.7883184 , -0.22791883,  3.0624709 , -0.12526794,
#          2.10388387,  1.95382612,  0.26365208,  0.95149854,  0.51185291,
#          1.68210162,  1.9801006 ,  1.03766205,  1.26248818,  0.35840294,
#          1.76652097,  1.70853243,  0.83232378,  0.07670593,  2.07905668,
#          0.13759722,  0.53422466,  0.29448919,  1.33529327,  1.00670407,
#         -0.2400356 ,  0.56030833,  0.45340462,  1.95734225,  3.40471405,
#          2.74134785,  2.7828061 ,  2.6378894 ,  0.61523508,  0.72483004,
#         -0.08327238,  2.1126525 ,  1.33851109,  0.18969924,  1.61342129,
#          1.0666095 ,  2.0515382 ,  0.88289079,  0.50111761,  1.10168649,
#          1.0074217 ,  1.96914352,  0.78687678,  0.65552161,  1.21866137,
#         -0.14025748,  0.56019575,  1.78654903,  0.14653901,  2.09670272,
#          0.44911585,  0.79657092,  1.54574235,  1.14462422, -0.21883751,
#         -0.57550459,  1.22937891,  0.04153446,  0.68634726,  1.60426333],
#        [ 0.77824238,  0.44133723, -0.12239775,  1.11180557,  3.31304908,
#          0.0612006 , -0.44608935,  0.60051202,  2.19493531,  0.71195987,
#          0.8751167 ,  0.92377948,  1.15997946,  0.06078636, -0.25739787,
#          0.9642561 ,  2.85280652, -0.6668979 ,  0.73670964,  0.72541357,
#          0.5569998 ,  1.13150226,  0.33129957,  1.8081254 ,  0.19334679,
#         -0.42105074,  0.79926608,  1.58407676,  3.86089649,  0.8093085 ,
#          2.67249422, -0.53736485,  1.92023269,  2.43781075,  0.94615474,
#          1.93315149,  0.72468208,  0.53039216,  0.84608352,  1.71594695,
#         -0.82251501,  2.43530007,  0.79681052,  0.45030409,  2.18137323,
#          1.24856335,  3.61432317, -0.08510804,  0.82606641,  0.56314328,
#          2.38030806,  0.26366729, -0.41927238, -1.51066014, -0.5542346 ,
#          1.01116482,  0.16795398,  2.18283875, -0.59505562,  0.82007191,
#         -0.50099517,  0.73721719,  0.14371691,  0.40124322, -1.02146554,
#          1.79542172,  0.17518909,  0.36059268,  0.2803326 ,  0.33545552,
#          2.10185252,  1.93774711,  1.04861565, -0.20298882,  0.99973309,
#          0.3914788 , -1.47589233,  0.16800164,  0.98358725,  0.09436082,
#          0.46626185,  1.77965158,  1.8776837 , -1.04359987,  1.22851061,
#          0.98912222,  1.24348689,  0.31800843,  1.07497627, -1.28658316,
#          0.48182702,  1.56380355, -0.45288581,  0.3104914 ,  0.0779445 ,
#          1.01324139,  1.95520345,  0.36528676,  2.82099877,  0.27298705]])

# %%
pl.plot(ReprRandAll[1], 'o')
# Out:
# [<matplotlib.lines.Line2D at 0x11536ddd0>,
#  <matplotlib.lines.Line2D at 0x11536ded0>,
#  <matplotlib.lines.Line2D at 0x11537a0d0>,
#  <matplotlib.lines.Line2D at 0x11537a1d0>,
#  <matplotlib.lines.Line2D at 0x11537a2d0>,
#  <matplotlib.lines.Line2D at 0x11537a3d0>,
#  <matplotlib.lines.Line2D at 0x11537a4d0>,
#  <matplotlib.lines.Line2D at 0x11537a5d0>,
#  <matplotlib.lines.Line2D at 0x11537a6d0>,
#  <matplotlib.lines.Line2D at 0x11537a7d0>,
#  <matplotlib.lines.Line2D at 0x11537a8d0>,
#  <matplotlib.lines.Line2D at 0x11537a9d0>,
#  <matplotlib.lines.Line2D at 0x11537aad0>,
#  <matplotlib.lines.Line2D at 0x11537abd0>,
#  <matplotlib.lines.Line2D at 0x121f07d10>,
#  <matplotlib.lines.Line2D at 0x11537add0>,
#  <matplotlib.lines.Line2D at 0x11537aed0>,
#  <matplotlib.lines.Line2D at 0x11537afd0>,
#  <matplotlib.lines.Line2D at 0x115384110>,
#  <matplotlib.lines.Line2D at 0x115384210>,
#  <matplotlib.lines.Line2D at 0x115384310>,
#  <matplotlib.lines.Line2D at 0x11537acd0>,
#  <matplotlib.lines.Line2D at 0x115384510>,
#  <matplotlib.lines.Line2D at 0x115384610>,
#  <matplotlib.lines.Line2D at 0x115384710>,
#  <matplotlib.lines.Line2D at 0x115384810>,
#  <matplotlib.lines.Line2D at 0x115384910>,
#  <matplotlib.lines.Line2D at 0x115384a10>,
#  <matplotlib.lines.Line2D at 0x115384410>,
#  <matplotlib.lines.Line2D at 0x115384c10>,
#  <matplotlib.lines.Line2D at 0x115384d10>,
#  <matplotlib.lines.Line2D at 0x115384e10>,
#  <matplotlib.lines.Line2D at 0x115384f10>,
#  <matplotlib.lines.Line2D at 0x11538f050>,
#  <matplotlib.lines.Line2D at 0x11538f150>,
#  <matplotlib.lines.Line2D at 0x115384b10>,
#  <matplotlib.lines.Line2D at 0x11538f350>,
#  <matplotlib.lines.Line2D at 0x11538f450>,
#  <matplotlib.lines.Line2D at 0x11538f550>,
#  <matplotlib.lines.Line2D at 0x11538f650>,
#  <matplotlib.lines.Line2D at 0x11538f750>,
#  <matplotlib.lines.Line2D at 0x11538f850>,
#  <matplotlib.lines.Line2D at 0x11538f250>,
#  <matplotlib.lines.Line2D at 0x11538fa50>,
#  <matplotlib.lines.Line2D at 0x11538fb50>,
#  <matplotlib.lines.Line2D at 0x11538fc50>,
#  <matplotlib.lines.Line2D at 0x11538fd50>,
#  <matplotlib.lines.Line2D at 0x11538fe50>,
#  <matplotlib.lines.Line2D at 0x11538ff50>,
#  <matplotlib.lines.Line2D at 0x11538f950>,
#  <matplotlib.lines.Line2D at 0x11539a190>,
#  <matplotlib.lines.Line2D at 0x11539a290>,
#  <matplotlib.lines.Line2D at 0x11539a390>,
#  <matplotlib.lines.Line2D at 0x11539a490>,
#  <matplotlib.lines.Line2D at 0x11539a590>,
#  <matplotlib.lines.Line2D at 0x11539a690>,
#  <matplotlib.lines.Line2D at 0x11539a090>,
#  <matplotlib.lines.Line2D at 0x11539a890>,
#  <matplotlib.lines.Line2D at 0x11539a990>,
#  <matplotlib.lines.Line2D at 0x11539aa90>,
#  <matplotlib.lines.Line2D at 0x11539ab90>,
#  <matplotlib.lines.Line2D at 0x11539ac90>,
#  <matplotlib.lines.Line2D at 0x11539ad90>,
#  <matplotlib.lines.Line2D at 0x11539a790>,
#  <matplotlib.lines.Line2D at 0x11539af90>,
#  <matplotlib.lines.Line2D at 0x1153a40d0>,
#  <matplotlib.lines.Line2D at 0x1153a41d0>,
#  <matplotlib.lines.Line2D at 0x1153a42d0>,
#  <matplotlib.lines.Line2D at 0x1153a43d0>,
#  <matplotlib.lines.Line2D at 0x1153a44d0>,
#  <matplotlib.lines.Line2D at 0x11539ae90>,
#  <matplotlib.lines.Line2D at 0x1153a46d0>,
#  <matplotlib.lines.Line2D at 0x1153a47d0>,
#  <matplotlib.lines.Line2D at 0x1153a48d0>,
#  <matplotlib.lines.Line2D at 0x1153a49d0>,
#  <matplotlib.lines.Line2D at 0x1153a4ad0>,
#  <matplotlib.lines.Line2D at 0x1153a4bd0>,
#  <matplotlib.lines.Line2D at 0x1153a45d0>,
#  <matplotlib.lines.Line2D at 0x1153a4dd0>,
#  <matplotlib.lines.Line2D at 0x1153a4ed0>,
#  <matplotlib.lines.Line2D at 0x1153a4fd0>,
#  <matplotlib.lines.Line2D at 0x1153af110>,
#  <matplotlib.lines.Line2D at 0x1153af210>,
#  <matplotlib.lines.Line2D at 0x1153af310>,
#  <matplotlib.lines.Line2D at 0x1153a4cd0>,
#  <matplotlib.lines.Line2D at 0x1153af510>,
#  <matplotlib.lines.Line2D at 0x1153af610>,
#  <matplotlib.lines.Line2D at 0x1153af710>,
#  <matplotlib.lines.Line2D at 0x1153af810>,
#  <matplotlib.lines.Line2D at 0x1153af910>,
#  <matplotlib.lines.Line2D at 0x1153afa10>,
#  <matplotlib.lines.Line2D at 0x1153af410>,
#  <matplotlib.lines.Line2D at 0x1153afc10>,
#  <matplotlib.lines.Line2D at 0x1153afd10>,
#  <matplotlib.lines.Line2D at 0x1153afe10>,
#  <matplotlib.lines.Line2D at 0x1153aff10>,
#  <matplotlib.lines.Line2D at 0x1153bb050>,
#  <matplotlib.lines.Line2D at 0x1153bb150>,
#  <matplotlib.lines.Line2D at 0x1153afb10>,
#  <matplotlib.lines.Line2D at 0x1153bb350>]
